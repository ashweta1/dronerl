# %% [markdown]
# <a href="https://colab.research.google.com/github/ashweta1/dronerl/blob/main/cs230_rectifying_facts_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rectifying Factual knowledge through RAG (Retrieval Augmented Generation)
#
# This colab uses RAG on wikipedia knowledge dataset, to prepend context to prompts.
#
# RAG is used from the library I wrote: git+https://github.com/ashweta1/rag_wiki.git

# %% [markdown]
# ## Prepare environment

# %%
# %%bash
#
# # check that colab exists
# !(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
#
# # recreate the local home for this colab run
# cd /content && rm -rf /content/home && mkdir home && cd home
#
# # install the known facts dataset.
# pip install git+https://github.com/kmeng01/rome.git/tree/main/dsets >> install.log 2>&1
#
# # install hugging face datasets library
# pip install datasets >> install.log 2>&1
#
# pip install git+https://github.com/ashweta1/rag_wiki.git >> install.log 2>&1
# pip list | grep rag_wiki
#
# # install latest torch and faiss-gpu
# pip uninstall -y torch faiss-cpu faiss-gpu >> install.log 2>&1
# pip install torch faiss-gpu >> install.log 2>&1
#
# # pip uninstall -y torch torchaudio torchvision torchtext torchdata faiss-gpu >> install.log 2>&1
# # pip install torch torchaudio torchvision torchtext torchdata faiss-gpu >> install.log 2>&1
# Out:
# rag_wiki                           0.1.0

# %%
from ctypes import pythonapi
# !python --version
# !python -c "import torch; print(torch.__version__)"
# !python -c "import faiss; print(faiss.__version__)"
# !python -c "import numpy; print(numpy.__version__)"
# Out:
# Python 3.10.12
# 2.5.1+cu124
# 1.7.2
# 1.26.4

# %%
IS_COLAB = True
try:
    import google.colab, torch, os

    IS_COLAB = True
    device = "cpu"
    if torch.cuda.is_available():
      device = torch.device("cuda")
    elif torch.backends.mps.is_available():
      device = torch.device("mps")
    else:
      device = torch.device("cpu")
    print("Device = ", device)
        # raise Exception("Change runtime type to include a GPU.")

    os.chdir("/content/home")
    torch.set_grad_enabled(False)  # no model parameter updates

except ModuleNotFoundError as _:
    pass
# Out:
# Device =  cuda

# %%
# %%bash
#
# # # Install my own rag_wiki library to use RAG from wikipeda
# # cd /content/home && rm -fr /content/home/rag_wiki
#
# # git clone https://github.com/ashweta1/rag_wiki.git && cd /content/home/rag_wiki && pip install -e . && cd /content/home
# # ls -R /content/home/rag_wiki/

# %%
# IPYTHON magic to automatically reload imported module if they change
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !nvidia-smi
# Out:
# Sat Nov 23 03:22:14 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8              11W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# Get wikipedia embeddings loaded
import torch
from rag_wiki import rag

print("torch.cuda.is_available()", torch.cuda.is_available())
print(torch.__version__)

# Load dataset
print("Loading dataset...")
dataset = rag.load_wiki_dataset(num_examples=100000, debug=True)
print("Loading dataset...done")
print("")

# Preprocess the dataset
print("Preprocessing dataset...")
index, texts = rag.preprocess(dataset, batch_size=200, debug=True)
print("Preprocessing dataset...done")
print("")
# Out:
# torch.cuda.is_available() True
# 2.5.1+cu124
# Loading dataset...
# Loading dataset from kilt_wikipedia
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 2
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 3
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 4
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 5
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 6
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 7
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 8
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 9
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 10
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 11
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 12
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 13
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 14
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 15
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 16
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 17
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 18
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 19
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 20
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 21
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 22
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 23
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 24
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 25
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 26
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 27
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 28
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 29
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 30
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 31
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 32
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 33
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 34
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 35
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 36
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 37
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 38
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 39
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 40
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 41
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 42
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 43
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 44
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 45
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 46
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 47
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 48
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 49
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 50
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 51
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 52
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 53
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 54
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 55
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 56
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 57
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 58
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 59
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 60
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 61
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 62
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 63
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 64
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 65
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 66
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 67
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 68
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 69
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 70
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 71
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 72
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 73
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 74
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 75
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 76
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 77
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 78
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 79
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 80
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 81
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 82
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 83
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 84
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 85
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 86
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 87
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 88
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 89
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 90
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 91
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 92
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 93
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 94
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 95
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 96
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 97
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 98
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 99
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 100
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 101
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 102
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 103
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 104
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 105
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 106
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 107
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 108
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 109
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 110
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 111
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 112
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 113
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 114
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 115
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 116
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 117
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 118
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 119
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 120
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 121
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 122
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 123
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 124
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 125
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 126
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 127
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 128
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 129
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 130
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 131
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 132
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 133
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 134
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 135
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# ...
# Adding embeddings to the index... done.
# Batch 456
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 457
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 458
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 459
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 460
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 461
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 462
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 463
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 464
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 465
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 466
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 467
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 468
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 469
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 470
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 471
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 472
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 473
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 474
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 475
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 476
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 477
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 478
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 479
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 480
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 481
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 482
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 483
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 484
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 485
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 486
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 487
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 488
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 489
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 490
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 491
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 492
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 493
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 494
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 495
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 496
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 497
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 498
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 499
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Batch 500
# Got 200 texts
# Getting batch texts... done.
# Encoding the dataset embeddings...
# torch embeddings tensor shape:  torch.Size([200, 384])
# numpy embeddings shape:  (200, 384)
# Encoding the dataset embeddings... done.
# #Dataset embeddings =  (200, 384) d =  384
# Adding embeddings to the index (dimension 384)...
# Adding embeddings to the index... done.
# Length of texts =  100000
# Preprocessing dataset...done

# %%
# Query the index and retrieve relevant texts
TOP_K_TEXTS = 1
prompts = ["What is the capital of India?",
           "Who is the president of the United States?",
           "What is the population of China?",
           "The captial of France is ",
           "Where is the Eiffel Tower located?"]

print("Retrieving relevant texts...")
print("Index: ", index)
print("Length of texts = ", len(texts))
retrieved_texts = rag.retrieve(prompts, index, texts, top_k=TOP_K_TEXTS, debug=False)
print("Retrieving relevant texts...done")
print("")
# Out:
# Retrieving relevant texts...
# Index:  <faiss.swigfaiss.GpuIndexFlat; proxy of <Swig Object of type 'faiss::gpu::GpuIndexFlat *' at 0x78522c303750> >
# Length of texts =  100000
# Retrieving relevant texts...done

# %%
for p, ts in zip(prompts, retrieved_texts):
    print(f"Prompt: {p}")
    print(f"Retrieved texts: {len(ts)}")
    print("")

prepend = "Based on the information provided, answer the question concisely. Do not repeat the prompt."
section1 = "[INFO]"
section2 = "[QUESTION]"
section3 = "[ANSWER]"
prompt_with_context = [prepend + "\n" + section1 + "\n" + "\n".join(ts)[:200] + "\n" + section2 + "\n" + p + "\n" + section3 + "\n" for p, ts in zip(prompts, retrieved_texts)]
# contexts = [f"{' '.join(ts)[:200]} {p}" for p, ts in zip(prompts, retrieved_texts)]
print("Prompts with contexts: ", prompt_with_context)
# Out:
# Prompt: What is the capital of India?
# Retrieved texts: 1
#
# Prompt: Who is the president of the United States?
# Retrieved texts: 1
#
# Prompt: What is the population of China?
# Retrieved texts: 1
#
# Prompt: The captial of France is
# Retrieved texts: 1
#
# Prompt: Where is the Eiffel Tower located?
# Retrieved texts: 1
#
# Prompts with contexts:  ['Based on the information provided, answer the question concisely. Do not repeat the prompt.\n[INFO]\n{\'paragraph\': [\'Bharat Ek Khoj\\n\', \'Bharat Ek Khoj ("The Discovery of India") is a 53-episode Indian historical drama based on the book "The Discovery of India" (1946) by Jawaharlal Nehru that covers \n[QUESTION]\nWhat is the capital of India?\n[ANSWER]\n', "Based on the information provided, answer the question concisely. Do not repeat the prompt.\n[INFO]\n{'paragraph': ['Presidential system\\n', 'A presidential system is a democratic and republican system of government where a head of government leads an executive branch that is separate from the legisl\n[QUESTION]\nWho is the president of the United States?\n[ANSWER]\n", 'Based on the information provided, answer the question concisely. Do not repeat the prompt.\n[INFO]\n{\'paragraph\': ["Culture of the People\'s Republic of China\\n", "The culture of the People\'s Republic of China is a rich and varied blend of traditional Chinese culture with communist and other internat\n[QUESTION]\nWhat is the population of China?\n[ANSWER]\n', "Based on the information provided, answer the question concisely. Do not repeat the prompt.\n[INFO]\n{'paragraph': ['Francophobia\\n', 'Anti-French sentiment (Francophobia) is an extreme or irrational fear or contempt of France, the French people, the French government or the Francophonie (set of poli\n[QUESTION]\nThe captial of France is \n[ANSWER]\n", "Based on the information provided, answer the question concisely. Do not repeat the prompt.\n[INFO]\n{'paragraph': ['Canton of Ébreuil\\n', 'The canton of Ébreuil is a former administrative division in central France. It was disbanded following the French canton reorganisation which came into effect i\n[QUESTION]\nWhere is the Eiffel Tower located?\n[ANSWER]\n"]

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

def get_gpt2_model():
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    model = GPT2LMHeadModel.from_pretrained('gpt2', pad_token_id=tokenizer.eos_token_id)
    #.to(device)
    return model, tokenizer
model, tokenizer = get_gpt2_model()

# %%
def generate_text(model, tokenizer, prompt, max_length=50, device=device):
    input_ids = tokenizer.encode(prompt, return_tensors='pt')

    outputs = model.generate(input_ids,
                             #.to(device),
                             max_length=10000,
                             do_sample=True,
                             num_beams=2,
                             temperature=0.1,
                             no_repeat_ngram_size=2,
                             early_stopping=True,
                             eos_token_id=tokenizer.encode(".")[0])

    # Decode the generated sequence back to text
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generated_text

# %%
generate_text(model, tokenizer, "The capital of France is")
# Out:
# 'The capital of France is in a state of war with Russia.'

# %%
generate_text(model, tokenizer, "The capital of India is")
# Out:
# 'The capital of India is home to more than 1.'

# %%
for p in prompts:
    print("Prompt: ", p)
    print("----")
    print(generate_text(model, tokenizer, p))
    print("=====")
    print("")
# Out:
# Prompt:  What is the capital of India?
# ----
# What is the capital of India?
#
# India is a country with a population of over 1.
# =====
#
# Prompt:  Who is the president of the United States?
# ----
# Who is the president of the United States?
#
# The president is elected by the people.
# =====
#
# Prompt:  What is the population of China?
# ----
# What is the population of China?
#
# The population is estimated to be about 1.
# =====
#
# Prompt:  The captial of France is
# ----
# The captial of France is vernacular, but it is not the only language spoken in the Middle East.
# =====
#
# Prompt:  Where is the Eiffel Tower located?
# ----
# Where is the Eiffel Tower located?
#
# Eiffels Tower is located in the heart of London.
# =====

# %%
for p in prompt_with_context:
    print("Prompt: ", p)
    print("----")
    print(generate_text(model, tokenizer, p))
    print("=====")
    print("")
# Out:
# Prompt:  Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ['Bharat Ek Khoj\n', 'Bharat Ek Khoj ("The Discovery of India") is a 53-episode Indian historical drama based on the book "The Discovery of India" (1946) by Jawaharlal Nehru that covers
# [QUESTION]
# What is the capital of India?
# [ANSWER]
#
# ----
# Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ['Bharat Ek Khoj\n', 'Bharat Ek Khoj ("The Discovery of India") is a 53-episode Indian historical drama based on the book "The Discovery of India" (1946) by Jawaharlal Nehru that covers
# [QUESTION]
# What is the capital of India?
# [ANSWER]
# India is an independent nation.
# =====
#
# Prompt:  Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ['Presidential system\n', 'A presidential system is a democratic and republican system of government where a head of government leads an executive branch that is separate from the legisl
# [QUESTION]
# Who is the president of the United States?
# [ANSWER]
#
# ----
# Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ['Presidential system\n', 'A presidential system is a democratic and republican system of government where a head of government leads an executive branch that is separate from the legisl
# [QUESTION]
# Who is the president of the United States?
# [ANSWER]
# The president is elected by the people.
# =====
#
# Prompt:  Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ["Culture of the People's Republic of China\n", "The culture of the People's Republic of China is a rich and varied blend of traditional Chinese culture with communist and other internat
# [QUESTION]
# What is the population of China?
# [ANSWER]
#
# ----
# Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ["Culture of the People's Republic of China\n", "The culture of the People's Republic of China is a rich and varied blend of traditional Chinese culture with communist and other internat
# [QUESTION]
# What is the population of China?
# [ANSWER]
# The population is estimated to be about 1.
# =====
#
# Prompt:  Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ['Francophobia\n', 'Anti-French sentiment (Francophobia) is an extreme or irrational fear or contempt of France, the French people, the French government or the Francophonie (set of poli
# [QUESTION]
# The captial of France is
# [ANSWER]
#
# ----
# Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ['Francophobia\n', 'Anti-French sentiment (Francophobia) is an extreme or irrational fear or contempt of France, the French people, the French government or the Francophonie (set of poli
# [QUESTION]
# The captial of France is
# [ANSWER]
# France is a nation of people who are not French, who do not speak French.
# =====
#
# Prompt:  Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ['Canton of Ébreuil\n', 'The canton of Ébreuil is a former administrative division in central France. It was disbanded following the French canton reorganisation which came into effect i
# [QUESTION]
# Where is the Eiffel Tower located?
# [ANSWER]
#
# ----
# Based on the information provided, answer the question concisely. Do not repeat the prompt.
# [INFO]
# {'paragraph': ['Canton of Ébreuil\n', 'The canton of Ébreuil is a former administrative division in central France. It was disbanded following the French canton reorganisation which came into effect i
# [QUESTION]
# Where is the Eiffel Tower located?
# [ANSWER]
# The tower is located in the centre of the city.
# =====
